# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Load Data

# %%
df = pd.read_csv('data/DadosFinaisEnrich.csv')

cols = df.columns.to_list()
cols.remove('NO_MUNICIPIO')
cols.remove('Homicidios')
cols.remove('Furto')
df.fillna(df.mean(), inplace=True)

df[cols] = (df[cols]-df[cols].min())/(df[cols].max()-df[cols].min())

df.head()
# Out:
#        NO_MUNICIPIO  IN_SALA_DIRETORIA_1  IN_INTERNET_1  IN_REDES_SOCIAIS_1  \
# 0        Adamantina             0.800000       0.800000            0.266667
# 1            Adolfo             1.000000       0.666667            0.000000
# 2             Aguaí             0.823529       0.882353            0.588235
# 3    Águas da Prata             0.500000       0.833333            0.000000
# 4  Águas de Lindóia             0.266667       0.466667            0.200000
#
#    IN_NOTURNO_1  IN_EJA_1  IN_SECRETARIA_1  IN_EQUIP_LOUSA_DIGITAL_1  \
# 0      0.066667  0.066667         0.733333                  0.066667
# 1      0.000000  0.000000         1.000000                  0.000000
# 2      0.058824  0.058824         0.882353                  0.411765
# 3      0.000000  0.000000         0.333333                  0.666667
# 4      0.066667  0.066667         0.400000                  0.000000
#
#    IN_SALA_PROFESSOR_1  IN_AREA_VERDE_1  ...  IDEB_anos_finais_ef      idhm  \
# 0             0.666667         0.133333  ...             0.482759  0.677130
# 1             1.000000         0.000000  ...             0.379310  0.408072
# 2             0.823529         0.058824  ...             0.482759  0.340807
# 3             0.666667         0.000000  ...             0.724138  0.636771
# 4             0.533333         0.066667  ...             0.482759  0.475336
#
#    pib_per_capta  mortalidade_infantil  esgotamento_sanitario_adequado  \
# 0       0.058034              0.007431                        0.943472
# 1       0.055332              0.084671                        0.920592
# 2       0.048151              0.062845                        0.866756
# 3       0.030499              0.084671                        0.791386
# 4       0.048476              0.017410                        0.904441
#
#     sus_hab  perc_populacao_exposta_risco  escolas_hab  homicidios_hab  \
# 0  0.128150                      0.000000     0.111096        0.069610
# 1  0.165963                      0.000000     0.250082        0.000000
# 2  0.195378                      0.000000     0.122025        0.099254
# 3  0.306127                      0.000000     0.210314        0.000000
# 4  0.300470                      0.433486     0.232542        0.000000
#
#    furtos_hab
# 0    0.060117
# 1    0.190939
# 2    0.106902
# 3    0.065585
# 4    0.126527
#
# [5 rows x 69 columns]

# %% [markdown]
# # 2. Analysis

# %% [markdown]
# The dataset counts with high dimensionality. This fact may denote that some variables may be highly correlated, and does not add information to the problem

# %%
sns.pairplot(df[['furtos_hab', 'homicidios_hab', 'idhm', 'escolas_hab', 'salario_medio_mensal_trabalhadores_formais', 'perc_pop_rend_per_capta_meio_sm']], height=5, aspect=1)

# %%
cols = df.columns.to_list()
cols.remove('NO_MUNICIPIO')
cols.remove('furtos_hab')
cols.remove('homicidios_hab')
cols.remove('Furto')
cols.remove('Homicidios')
cols.remove('nEscolas')
cols.remove('populacao_estimada')

df_hist = df[cols].hist(figsize=(25, 20))

# %%
cols = df.columns.to_list()
cols.remove('NO_MUNICIPIO')
cols.remove('furtos_hab')
cols.remove('homicidios_hab')
cols.remove('Furto')
cols.remove('Homicidios')
cols.remove('nEscolas')
cols.remove('populacao_estimada')
# print(len(cols))

# fig, axes = plt.subplots(nrows=7, ncols=1)

# df[cols[0:10]].boxplot(rot=90, ax=axes[0])
# df[cols[10:20]].boxplot(rot=90, ax=axes[1])

df[cols].boxplot(rot=90, figsize=(25, 15))
# Out:
# <AxesSubplot:>

# %%
filter = (((corr >= 0.5) | (corr <= -0.5)) & (corr != 1)).any()
sub_df = corr.loc[: , filter]
# sub_df
sns.set(rc = {'figure.figsize':(30,30)})
ax = sns.heatmap(sub_df, annot=True)

g1 = ['IN_SALA_DIRETORIA_1', 'IN_SALA_PROFESSOR_1']
g2 = ['IN_NOTURNO_1', 'IN_EJA_1']
g3 = ['IN_EQUIP_LOUSA_DIGITAL_1', 'QT_EQUIP_LOUSA_DIGITAL_1']
g4 = ['IN_ORGAO_ASS_PAIS_1', 'IN_ORGAO_ASS_PAIS_MESRES_1', 'IN_ORGAO_CONSELHO_ESCOLAR_1', 'IN_ORGAO_GREMIO_ESTUDANTIL_1']
g5 = ['QT_MAT_BAS_1', 'Alunos_Turma_1', 'QT_SALAS_UTILIZADAS_1', 'QT_MAT_BAS_0_3_1', 'QT_MAT_BAS_4_5_1', 'QT_MAT_BAS_6_10_1', 'QT_MAT_BAS_11_14_1', 
      'QT_MAT_BAS_15_17_1', 'QT_MAT_BAS_18_MAIS_1', 'QT_TUR_BAS_1', 'QT_MAT_EJA_1', 'escolas_hab']
g6 = ['QT_EQUIP_INFORMATICA', 'Equipamento_Inform_1', 'Lab_Inform_1']
g7 = ['IN_EQUIP_LOUSA_DIGITAL_1', 'QT_EQUIP_LOUSA_DIGITAL_1']

# %%
# Isolation Forest
from sklearn.ensemble import IsolationForest

g0 = ['IN_SALA_DIRETORIA_1', 'IN_SALA_PROFESSOR_1']
g1 = ['IN_NOTURNO_1', 'IN_EJA_1']
g2 = ['IN_EQUIP_LOUSA_DIGITAL_1', 'QT_EQUIP_LOUSA_DIGITAL_1']
g3 = ['IN_ORGAO_ASS_PAIS_1', 'IN_ORGAO_ASS_PAIS_MESTRES_1', 'IN_ORGAO_CONSELHO_ESCOLAR_1', 'IN_ORGAO_GREMIO_ESTUDANTIL_1']
g4 = ['QT_MAT_BAS_1', 'Alunos_Turma_1', 'QT_SALAS_UTILIZADAS_1', 'QT_MAT_BAS_0_3_1', 'QT_MAT_BAS_4_5_1', 'QT_MAT_BAS_6_10_1', 'QT_MAT_BAS_11_14_1', 
      'QT_MAT_BAS_15_17_1', 'QT_MAT_BAS_18_MAIS_1', 'QT_TUR_BAS_1', 'QT_MAT_EJA_1', 'escolas_hab']
g5 = ['QT_EQUIP_INFORMATICA', 'Equipamento_Inform_1', 'Lab_Inform_1']
g6 = ['IN_EQUIP_LOUSA_DIGITAL_1', 'QT_EQUIP_LOUSA_DIGITAL_1']

groups = [g0, g1, g2, g3, g4, g5, g6]

random_state = np.random.RandomState(42)

cols = df.columns.to_list()
# cols.remove('NO_MUNICIPIO')
cols.remove('Homicidios')
cols.remove('Furto')

df_temp = df[cols].copy()

model=IsolationForest(n_estimators=100,max_samples='auto',contamination=float(0.05),random_state=random_state)


for i, g in enumerate(groups):
    
    model.fit(df_temp[g])

    # print(model.get_params())
    

    df_temp[f'scores_{i}'] = model.decision_function(df_temp[g])

    df_temp[f'anomaly_score_{i}'] = model.predict(df_temp[g])

df_temp[((df_temp[f'anomaly_score_1']==-1) | (df_temp[f'anomaly_score_2']==-1) | (df_temp[f'anomaly_score_3']==-1) | (df_temp[f'anomaly_score_4']==-1) | (df_temp[f'anomaly_score_5']==-1) |
        (df_temp[f'anomaly_score_6']==-1) | (df_temp[f'anomaly_score_0']==-1))]
# Out:
#              NO_MUNICIPIO  IN_SALA_DIRETORIA_1  IN_INTERNET_1  \
# 2                   Aguaí             0.823529       0.882353
# 3          Águas da Prata             0.500000       0.833333
# 4        Águas de Lindóia             0.266667       0.466667
# 6      Águas de São Pedro             1.000000       1.000000
# 13               Alumínio             0.363636       0.000000
# ..                    ...                  ...            ...
# 630       Valentim Gentil             0.500000       1.000000
# 633                Vargem             0.300000       0.200000
# 640  Vista Alegre do Alto             1.000000       0.500000
# 641        Vitória Brasil             0.000000       1.000000
# 643           Votuporanga             0.967742       1.000000
#
#      IN_REDES_SOCIAIS_1  IN_NOTURNO_1  IN_EJA_1  IN_SECRETARIA_1  \
# 2              0.588235      0.058824  0.058824         0.882353
# 3              0.000000      0.000000  0.000000         0.333333
# 4              0.200000      0.066667  0.066667         0.400000
# 6              0.500000      0.000000  0.000000         0.500000
# 13             0.000000      0.090909  0.090909         0.818182
# ..                  ...           ...       ...              ...
# 630            0.000000      0.000000  0.000000         1.000000
# 633            0.100000      0.000000  0.000000         0.100000
# 640            0.000000      0.000000  0.000000         1.000000
# 641            0.500000      0.000000  0.000000         1.000000
# 643            0.000000      0.032258  0.032258         0.677419
#
#      IN_EQUIP_LOUSA_DIGITAL_1  IN_SALA_PROFESSOR_1  IN_AREA_VERDE_1  ...  \
# 2                    0.411765             0.823529         0.058824  ...
# 3                    0.666667             0.666667         0.000000  ...
# 4                    0.000000             0.533333         0.066667  ...
# 6                    0.000000             1.000000         0.000000  ...
# 13                   0.000000             0.545455         0.000000  ...
# ..                        ...                  ...              ...  ...
# 630                  0.500000             0.500000         0.000000  ...
# 633                  0.000000             0.300000         0.000000  ...
# 640                  0.000000             0.500000         0.000000  ...
# 641                  0.000000             0.500000         0.000000  ...
# 643                  0.838710             0.838710         0.032258  ...
#
#      scores_2  anomaly_score_2  scores_3  anomaly_score_3  scores_4  \
# 2    0.121863                1  0.151192                1  0.124516
# 3   -0.000216               -1  0.056404                1  0.157736
# 4    0.270187                1  0.148943                1  0.113671
# 6    0.270187                1  0.252149                1  0.026093
# 13   0.270187                1 -0.073894               -1  0.131093
# ..        ...              ...       ...              ...       ...
# 630  0.154704                1  0.038589                1 -0.150249
# 633  0.270187                1  0.108223                1  0.109772
# 640  0.270187                1  0.149367                1 -0.018049
# 641  0.270187                1  0.155119                1  0.141614
# 643 -0.058367               -1  0.237657                1  0.154496
#
#      anomaly_score_4  scores_5  anomaly_score_5  scores_6  anomaly_score_6
# 2                  1 -0.006065               -1  0.125045                1
# 3                  1  0.073407                1 -0.003712               -1
# 4                  1  0.180161                1  0.267111                1
# 6                  1 -0.134739               -1  0.267111                1
# 13                 1  0.042566                1  0.267111                1
# ..               ...       ...              ...       ...              ...
# 630               -1  0.192994                1  0.155643                1
# 633                1  0.060086                1  0.267111                1
# 640               -1 -0.001136               -1  0.267111                1
# 641                1  0.107407                1  0.267111                1
# 643                1  0.174284                1 -0.065989               -1
#
# [157 rows x 81 columns]

# %%
sns.pairplot(df[g6], height=5, aspect=1)

# %%
cond_out = ((df_temp[f'anomaly_score_1']==-1) | (df_temp[f'anomaly_score_2']==-1) | (df_temp[f'anomaly_score_3']==-1) | (df_temp[f'anomaly_score_4']==-1) | (df_temp[f'anomaly_score_5']==-1) |
        (df_temp[f'anomaly_score_6']==-1) | (df_temp[f'anomaly_score_0']==-1))

df_temp = df_temp[cond_out]
df_temp.fillna(df_temp[~cond_out].mean(), inplace=True)

# %%
df_temp[~cond_out]
# Out:
# c:\users\caiof\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-119-fb105cb6dd91> in <module>
# ----> 1 df_temp[~cond_out]
#
# c:\users\caiof\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# c:\users\caiof\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2947         # check_bool_indexer will throw exception if Series key cannot
#    2948         # be reindexed to match DataFrame rows
# -> 2949         key = check_bool_indexer(self.index, key)
#    2950         indexer = key.nonzero()[0]
#    2951         return self._take_with_is_copy(indexer, axis=0)
#
# c:\users\caiof\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2181         if mask.any():
#    2182             raise IndexingError(
# -> 2183                 "Unalignable boolean Series provided as "
#    2184                 "indexer (index of the boolean Series and of "
#    2185                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
LF = Q1 - 1.5*IQR
UF = Q3 + 1.5*IQR

cols_norm = ['Atividades_complementares_1', 'IN_QUADRA_ESPORTES_1', 'Equipamento_Inform_1', 'Material_Ped_1', 'Alunos_Turma_1', 'ANO_LETIVO_1', 'Espacos_1', 'Equip_1', 'QT_MAT_BAS_6_10_1',
            'QT_TUR_BAS_1', 'idhm', 'IDEB_anos_finais_ef', 'IDEB_anos_iniciais_ef', ]
cols_iqr = [el for el in cols if el not in cols_norm]

df_qt_outliers = ((df < LF) | (df > UF)).sum()

df[cols_iqr] = df[cols_iqr][(df[cols_iqr] < LF) | (df[cols_iqr] < UF)]

ub = df[cols_norm].mean() + 3 * df[cols_norm].std()
lb = df[cols_norm].mean() - 3 * df[cols_norm].std()

df[cols_norm] = df[cols_norm][(df[cols_norm] < lb) | (df[cols_norm] < ub)]

cols_drop = ['QT_EQUIP_LOUSA_DIGITAL_1', 'perc_populacao_exposta_risco']

df.drop(cols_drop, axis=1, inplace=True)
df.fillna(df.mean(), inplace=True)

# df_hist = df[cols_norm].hist()

# df[cols] = df[cols][(df > LF) & (df < UF)]
# df[(df < LF) | (df < UF)]

# %%
df_hist = df.hist(figsize=(25, 20))

# %%
df.boxplot(rot=90, figsize=(25, 15))
# Out:
# <AxesSubplot:>

# %%
cols = df.columns.to_list()

corr_pearson = df[cols].corr()
corr_spearman = df[cols].corr(method='spearman')

corr_nl = corr_spearman[['furtos_hab', 'homicidios_hab']].drop(['Furto', 'Homicidios', 'nEscolas', 'furtos_hab', 'homicidios_hab', 'populacao_estimada'])
corr_l = corr_pearson[['furtos_hab', 'homicidios_hab']].drop(['Furto', 'Homicidios', 'nEscolas', 'furtos_hab', 'homicidios_hab', 'populacao_estimada'])

corr_final = pd.merge(corr_l, corr_nl, left_index=True, right_index=True, suffixes=['_linear', '_non_linear'])

corr_final.sort_values(by='furtos_hab_non_linear')
# Out:
#                                             furtos_hab_linear  \
# QT_PROF_NUTRICIONISTA_1                             -0.162773
# tx_escolarizacao_16_14                              -0.080768
# Equip_1                                             -0.107151
# mortalidade_infantil                                -0.089538
# IN_INTERNET_1                                       -0.014833
# sus_hab                                             -0.043028
# IN_SALA_PROFESSOR_1                                 -0.058610
# IN_REFEITORIO_1                                     -0.037292
# IDEB_anos_finais_ef                                 -0.072157
# IN_SALA_DIRETORIA_1                                  0.005258
# IN_SECRETARIA_1                                     -0.038601
# escolas_hab                                          0.005949
# ACESSIBILIDADE_1                                    -0.066988
# IDEB_anos_iniciais_ef                               -0.052686
# ANO_LETIVO_1                                        -0.003853
# Atividades_complementares_1                         -0.030091
# QT_PROF_SERVICOS_GERAIS_1                           -0.038730
# IN_BANHEIRO_CHUVEIRO_1                              -0.067819
# IN_REDES_SOCIAIS_1                                  -0.061964
# perc_pop_rend_per_capta_meio_sm                      0.072099
# QT_PROF_BIBLIOTECARIO_1                             -0.038060
# Espacos_1                                           -0.042587
# QT_EQ_MULTIMIDIA                                    -0.025557
# QT_PROF_SUPORTE                                      0.017431
# IN_QUADRA_ESPORTES_1                                 0.053307
# QT_PROF_COORDENADOR_1                                0.032976
# Lab_Inform_1                                         0.040460
# QT_MAT_BAS_0_3_1                                     0.015442
# QT_SALAS_UTILIZADAS_1                                0.048422
# QT_PROF_ALIMENTACAO_1                                0.047327
# QT_DOC_BAS_1                                         0.038754
# Material_Ped_1                                       0.049866
# QT_EQUIP_INFORMATICA                                 0.073945
# Equipamento_Inform_1                                 0.031563
# IN_EQUIP_LOUSA_DIGITAL_1                            -0.020210
# COMUNIDADE_1                                         0.029924
# QT_TUR_BAS_1                                         0.083446
# IN_AREA_VERDE_1                                     -0.005429
# esgotamento_sanitario_adequado                       0.064044
# salario_medio_mensal_trabalhadores_formais           0.104408
# IN_ORGAO_ASS_PAIS_1                                  0.125134
# IN_ORGAO_ASS_PAIS_MESTRES_1                          0.175202
# IN_BIBLIOTECA_1                                      0.075250
# QT_MAT_BAS_4_5_1                                     0.098456
# QT_PROF_MONITORES_1                                  0.058730
# QT_PROF_ADMINISTRATIVOS_1                            0.107237
# QT_MAT_EJA_1                                         0.124868
# IN_ORGAO_CONSELHO_ESCOLAR_1                          0.154148
# QT_MAT_BAS_6_10_1                                    0.120425
# IN_ORGAO_GREMIO_ESTUDANTIL_1                         0.143915
# IN_NOTURNO_1                                         0.067891
# IN_EJA_1                                             0.086602
# QT_MAT_BAS_1                                         0.132947
# QT_MAT_BAS_18_MAIS_1                                 0.135125
# QT_MAT_BAS_15_17_1                                   0.127989
# densidade_demografica                                0.113699
# idhm                                                 0.125272
# QT_MAT_BAS_11_14_1                                   0.133182
# Alunos_Turma_1                                       0.159476
# pib_per_capta                                        0.201513
#
#                                             homicidios_hab_linear  \
# QT_PROF_NUTRICIONISTA_1                                 -0.034043
# tx_escolarizacao_16_14                                  -0.023573
# Equip_1                                                  0.000023
# mortalidade_infantil                                     0.015190
# IN_INTERNET_1                                            0.032607
# sus_hab                                                  0.001562
# IN_SALA_PROFESSOR_1                                     -0.008398
# IN_REFEITORIO_1                                         -0.023134
# IDEB_anos_finais_ef                                     -0.072627
# IN_SALA_DIRETORIA_1                                     -0.060834
# IN_SECRETARIA_1                                         -0.030454
# escolas_hab                                              0.030674
# ACESSIBILIDADE_1                                         0.007425
# IDEB_anos_iniciais_ef                                   -0.161748
# ANO_LETIVO_1                                             0.005905
# Atividades_complementares_1                              0.007085
# QT_PROF_SERVICOS_GERAIS_1                                0.004318
# IN_BANHEIRO_CHUVEIRO_1                                  -0.016375
# IN_REDES_SOCIAIS_1                                      -0.017891
# perc_pop_rend_per_capta_meio_sm                          0.134402
# QT_PROF_BIBLIOTECARIO_1                                 -0.090795
# Espacos_1                                               -0.023029
# QT_EQ_MULTIMIDIA                                        -0.057675
# QT_PROF_SUPORTE                                          0.004511
# IN_QUADRA_ESPORTES_1                                    -0.107601
# QT_PROF_COORDENADOR_1                                   -0.020898
# Lab_Inform_1                                            -0.027967
# QT_MAT_BAS_0_3_1                                        -0.005495
# QT_SALAS_UTILIZADAS_1                                    0.027145
# QT_PROF_ALIMENTACAO_1                                   -0.053544
# QT_DOC_BAS_1                                            -0.008596
# Material_Ped_1                                           0.043917
# QT_EQUIP_INFORMATICA                                    -0.033976
# Equipamento_Inform_1                                     0.011222
# IN_EQUIP_LOUSA_DIGITAL_1                                -0.034092
# COMUNIDADE_1                                             0.087185
# QT_TUR_BAS_1                                            -0.002727
# IN_AREA_VERDE_1                                         -0.006207
# esgotamento_sanitario_adequado                          -0.090438
# salario_medio_mensal_trabalhadores_formais               0.028401
# IN_ORGAO_ASS_PAIS_1                                      0.011445
# IN_ORGAO_ASS_PAIS_MESTRES_1                              0.007859
# IN_BIBLIOTECA_1                                          0.030343
# QT_MAT_BAS_4_5_1                                         0.013436
# QT_PROF_MONITORES_1                                     -0.012012
# QT_PROF_ADMINISTRATIVOS_1                                0.006902
# QT_MAT_EJA_1                                            -0.010525
# IN_ORGAO_CONSELHO_ESCOLAR_1                              0.019314
# QT_MAT_BAS_6_10_1                                       -0.009007
# IN_ORGAO_GREMIO_ESTUDANTIL_1                             0.016922
# IN_NOTURNO_1                                            -0.055995
# IN_EJA_1                                                -0.029154
# QT_MAT_BAS_1                                             0.017110
# QT_MAT_BAS_18_MAIS_1                                    -0.024583
# QT_MAT_BAS_15_17_1                                       0.015579
# densidade_demografica                                    0.013703
# idhm                                                    -0.100670
# QT_MAT_BAS_11_14_1                                       0.020486
# Alunos_Turma_1                                           0.009286
# pib_per_capta                                            0.090187
#
#                                             furtos_hab_non_linear  \
# QT_PROF_NUTRICIONISTA_1                                 -0.167468
# tx_escolarizacao_16_14                                  -0.121907
# Equip_1                                                 -0.114001
# mortalidade_infantil                                    -0.108783
# IN_INTERNET_1                                           -0.088368
# sus_hab                                                 -0.083616
# IN_SALA_PROFESSOR_1                                     -0.078947
# IN_REFEITORIO_1                                         -0.076962
# IDEB_anos_finais_ef                                     -0.073056
# IN_SALA_DIRETORIA_1                                     -0.065484
# IN_SECRETARIA_1                                         -0.061300
# escolas_hab                                             -0.059474
# ACESSIBILIDADE_1                                        -0.047764
# IDEB_anos_iniciais_ef                                   -0.045123
# ANO_LETIVO_1                                            -0.028033
# Atividades_complementares_1                             -0.027271
# QT_PROF_SERVICOS_GERAIS_1                               -0.027039
# IN_BANHEIRO_CHUVEIRO_1                                  -0.016722
# IN_REDES_SOCIAIS_1                                      -0.005444
# perc_pop_rend_per_capta_meio_sm                         -0.000861
# QT_PROF_BIBLIOTECARIO_1                                  0.002104
# Espacos_1                                                0.004082
# QT_EQ_MULTIMIDIA                                         0.015565
# QT_PROF_SUPORTE                                          0.015796
# IN_QUADRA_ESPORTES_1                                     0.032049
# QT_PROF_COORDENADOR_1                                    0.033760
# Lab_Inform_1                                             0.034475
# QT_MAT_BAS_0_3_1                                         0.039217
# QT_SALAS_UTILIZADAS_1                                    0.039249
# QT_PROF_ALIMENTACAO_1                                    0.049223
# QT_DOC_BAS_1                                             0.053280
# Material_Ped_1                                           0.057743
# QT_EQUIP_INFORMATICA                                     0.070880
# Equipamento_Inform_1                                     0.073688
# IN_EQUIP_LOUSA_DIGITAL_1                                 0.077674
# COMUNIDADE_1                                             0.084257
# QT_TUR_BAS_1                                             0.084500
# IN_AREA_VERDE_1                                          0.102498
# esgotamento_sanitario_adequado                           0.115434
# salario_medio_mensal_trabalhadores_formais               0.118610
# IN_ORGAO_ASS_PAIS_1                                      0.123089
# IN_ORGAO_ASS_PAIS_MESTRES_1                              0.125561
# IN_BIBLIOTECA_1                                          0.131987
# QT_MAT_BAS_4_5_1                                         0.133995
# QT_PROF_MONITORES_1                                      0.138126
# QT_PROF_ADMINISTRATIVOS_1                                0.139561
# QT_MAT_EJA_1                                             0.142175
# IN_ORGAO_CONSELHO_ESCOLAR_1                              0.143274
# QT_MAT_BAS_6_10_1                                        0.146601
# IN_ORGAO_GREMIO_ESTUDANTIL_1                             0.152661
# IN_NOTURNO_1                                             0.153661
# IN_EJA_1                                                 0.157535
# QT_MAT_BAS_1                                             0.158623
# QT_MAT_BAS_18_MAIS_1                                     0.160251
# QT_MAT_BAS_15_17_1                                       0.162735
# densidade_demografica                                    0.162757
# idhm                                                     0.179801
# QT_MAT_BAS_11_14_1                                       0.191222
# Alunos_Turma_1                                           0.201670
# pib_per_capta                                            0.304826
#
#                                             homicidios_hab_non_linear
# QT_PROF_NUTRICIONISTA_1                                     -0.168050
# tx_escolarizacao_16_14                                      -0.154094
# Equip_1                                                     -0.094915
# mortalidade_infantil                                        -0.100725
# IN_INTERNET_1                                               -0.098638
# sus_hab                                                     -0.154156
# IN_SALA_PROFESSOR_1                                         -0.099676
# IN_REFEITORIO_1                                             -0.013719
# IDEB_anos_finais_ef                                         -0.100254
# IN_SALA_DIRETORIA_1                                         -0.134249
# IN_SECRETARIA_1                                             -0.095489
# escolas_hab                                                 -0.136991
# ACESSIBILIDADE_1                                            -0.006280
# IDEB_anos_iniciais_ef                                       -0.133925
# ANO_LETIVO_1                                                 0.005462
# Atividades_complementares_1                                 -0.096434
# QT_PROF_SERVICOS_GERAIS_1                                   -0.024549
# IN_BANHEIRO_CHUVEIRO_1                                      -0.061705
# IN_REDES_SOCIAIS_1                                           0.029281
# perc_pop_rend_per_capta_meio_sm                              0.143396
# QT_PROF_BIBLIOTECARIO_1                                     -0.060346
# Espacos_1                                                    0.000406
# QT_EQ_MULTIMIDIA                                            -0.036807
# QT_PROF_SUPORTE                                              0.017725
# IN_QUADRA_ESPORTES_1                                        -0.063504
# QT_PROF_COORDENADOR_1                                        0.001863
# Lab_Inform_1                                                -0.002257
# QT_MAT_BAS_0_3_1                                             0.096390
# QT_SALAS_UTILIZADAS_1                                        0.064125
# QT_PROF_ALIMENTACAO_1                                       -0.006695
# QT_DOC_BAS_1                                                 0.082609
# Material_Ped_1                                               0.034444
# QT_EQUIP_INFORMATICA                                         0.005627
# Equipamento_Inform_1                                         0.016898
# IN_EQUIP_LOUSA_DIGITAL_1                                     0.105609
# COMUNIDADE_1                                                 0.085518
# QT_TUR_BAS_1                                                 0.105813
# IN_AREA_VERDE_1                                              0.080632
# esgotamento_sanitario_adequado                               0.056142
# salario_medio_mensal_trabalhadores_formais                   0.129007
# IN_ORGAO_ASS_PAIS_1                                          0.156277
# IN_ORGAO_ASS_PAIS_MESTRES_1                                  0.151979
# IN_BIBLIOTECA_1                                              0.161376
# QT_MAT_BAS_4_5_1                                             0.134930
# QT_PROF_MONITORES_1                                          0.065178
# QT_PROF_ADMINISTRATIVOS_1                                    0.064290
# QT_MAT_EJA_1                                                 0.189780
# IN_ORGAO_CONSELHO_ESCOLAR_1                                  0.154306
# QT_MAT_BAS_6_10_1                                            0.121830
# IN_ORGAO_GREMIO_ESTUDANTIL_1                                 0.145000
# IN_NOTURNO_1                                                 0.160815
# IN_EJA_1                                                     0.185323
# QT_MAT_BAS_1                                                 0.172963
# QT_MAT_BAS_18_MAIS_1                                         0.193130
# QT_MAT_BAS_15_17_1                                           0.117399
# densidade_demografica                                        0.252588
# idhm                                                         0.058237
# QT_MAT_BAS_11_14_1                                           0.112773
# Alunos_Turma_1                                               0.153043
# pib_per_capta                                                0.152801

# %% [markdown]
# # 3. Regression Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.inspection import permutation_importance


model = DecisionTreeRegressor(criterion='poisson', splitter='random')

cols = df.columns.to_list()
cols.remove('NO_MUNICIPIO')
cols.remove('furtos_hab')
cols.remove('homicidios_hab')
cols.remove('Furto')
cols.remove('Homicidios')
cols.remove('nEscolas')


df_temp = df[cols]


model.fit(df[cols], df['furtos_hab'])

importance = model.feature_importances_

importance_perm = permutation_importance(model, df[cols], df['furtos_hab'], n_repeats=10, random_state=0)

# pd.DataFrame(importance_perm['importances_mean']).plot.bar()
importance_df = pd.DataFrame({'variable': cols, 'importance' : importance_perm['importances_mean'].tolist()})

importance_df[importance_df['importance'] > 0].sort_values(by='importance').plot.bar(x='variable', y='importance', figsize=(25, 5))
# Out:
# <AxesSubplot:xlabel='variable'>

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

cols = df.columns.to_list()
cols.remove('NO_MUNICIPIO')
cols.remove('furtos_hab')
cols.remove('homicidios_hab')
cols.remove('Furto')
cols.remove('Homicidios')
cols.remove('nEscolas')
cols.remove('populacao_estimada')


model.fit(df[cols], df['furtos_hab'])

importance_perm = permutation_importance(model, df[cols], df['furtos_hab'], n_repeats=10, random_state=0)

# pd.DataFrame(importance_perm['importances_mean']).plot.bar()
importance_df = pd.DataFrame({'variable': cols, 'importance' : importance_perm['importances_mean'].tolist()})

importance_df[importance_df['importance'] > 0].sort_values(by='importance').plot.bar(x='variable', y='importance', figsize=(25, 5))
# Out:
# <AxesSubplot:xlabel='variable'>
