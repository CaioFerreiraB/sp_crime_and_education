# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Load Data

# %%
df = pd.read_csv('data/DadosFinaisEnrich.csv')

# %% [markdown]
# # 2. Analysis

# %% [markdown]
# The dataset counts with high dimensionality. This fact may denote that some variables may be highly correlated, and does not add information to the problem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Columns: 146 entries, NO_MUNICIPIO to escolas_hab
# dtypes: float64(135), int64(10), object(1)
# memory usage: 735.8+ KB

# %%
df.columns.to_list()
# Out:
# ['NO_MUNICIPIO',
#  'IN_ALMOXARIFADO_1',
#  'IN_AREA_VERDE_1',
#  'IN_BANHEIRO_EI_1',
#  'IN_BANHEIRO_PNE_1',
#  'IN_BANHEIRO_FUNCIONARIOS_1',
#  'IN_BANHEIRO_CHUVEIRO_1',
#  'IN_BIBLIOTECA_1',
#  'IN_BIBLIOTECA_SALA_LEITURA_1',
#  'IN_DESPENSA_1',
#  'IN_LABORATORIO_INFORMATICA_1',
#  'IN_PATIO_COBERTO_1',
#  'IN_PATIO_DESCOBERTO_1',
#  'IN_PARQUE_INFANTIL_1',
#  'IN_QUADRA_ESPORTES_1',
#  'IN_QUADRA_ESPORTES_COBERTA_1',
#  'IN_QUADRA_ESPORTES_DESCOBERTA_1',
#  'IN_REFEITORIO_1',
#  'IN_SALA_ATELIE_ARTES_1',
#  'IN_SALA_MULTIUSO_1',
#  'IN_SALA_DIRETORIA_1',
#  'IN_SALA_LEITURA_1',
#  'IN_SALA_PROFESSOR_1',
#  'IN_SECRETARIA_1',
#  'IN_SALA_ATENDIMENTO_ESPECIAL_1',
#  'IN_ACESSIBILIDADE_CORRIMAO_1',
#  'IN_ACESSIBILIDADE_PISOS_TATEIS_1',
#  'IN_ACESSIBILIDADE_VAO_LIVRE_1',
#  'IN_ACESSIBILIDADE_RAMPAS_1',
#  'IN_ACESSIBILIDADE_INEXISTENTE_1',
#  'IN_EQUIP_PARABOLICA_1',
#  'IN_EQUIP_COPIADORA_1',
#  'IN_EQUIP_IMPRESSORA_1',
#  'IN_EQUIP_IMPRESSORA_MULT_1',
#  'IN_EQUIP_SCANNER_1',
# ...

# %%
df['Homicidios'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['furtos_hab', 'homicidios_hab', 'idhm', 'escolas_hab']])

# %%
corr = df[['furtos_hab', 'homicidios_hab', 'idhm', 'QT_MAT_BAS_0_3_1', 'QT_MAT_BAS_4_5_1', 'QT_MAT_BAS_6_10_1', 'QT_MAT_BAS_11_14_1', 'QT_MAT_BAS_15_17_1', 'QT_MAT_BAS_18_MAIS_1', 
          'salario_medio_mensal_trabalhadores_formais', 'perc_pop_rend_per_capta_meio_sm']].corr()

sns.set(rc = {'figure.figsize':(25,20)})
ax = sns.heatmap(corr, annot=True)
